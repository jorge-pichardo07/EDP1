# %% [markdown]
# <a href="https://colab.research.google.com/github/jorge-pichardo07/EDP1/blob/main/Graficas_Sympy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import *

# %% [markdown]
# Importa todas las funciones de la libreria Sympy

# %%
x=symbols('x')

# %% [markdown]
# Llamamos a la variable x la funcion de symbols

# %%
c1=plotting.plot(x*x)

# %% [markdown]
# la herramienta plotting.plot grafíca una función, en este caso está graficando a $x^2$

# %%
cl=plotting.plot(x*x,show=False)
c2=plotting.plot(x**3,show=False)

# %% [markdown]
# Aqui en el argumento se usa show=False esto indica que no se mostrará el gráfico en la pantalla

# %%
c1 #Indica qué es y en qué espacio de memoria está

# %%
c1.append(c2[0]) #Anida las gráficas sin los ejes

# %%
c1

# %%
c1.show()

# %% [markdown]
# se muestra el resultado de C1 anidado al C2 del comando c1.append(c2[0]

# %%
c1.extend(c2)

# %% [markdown]
# Agrega al mismo plano las dos funciones

# %%
c1.show()

# %%
c2.show()

# %% [markdown]
# c2.show() muestra la grafica solo poniendo el codigo

# %%
from sympy.plotting import plot

# %%
plot(x**2)

# %% [markdown]
# Grafica la funcion de $x^2$

# %%
plot(x**2,(x,-1,1))

# %% [markdown]
# Muestra la grafica con parametros de -1 a 1

# %%
plot(exp(x))
plot(exp(x),(x,0,2))

# %% [markdown]
# Muestra la grafica de exponencial de x con el simbolo exp() y lo que esta entre parentesis muestra los parametros en x (los cuales son de 0 a 2)

# %%
plot(x,x**2,x**3, (x,-2,2))

# %% [markdown]
# Muestra las graficas de una linea recta (X) una parabola ($x^2$) y una funcion cubica ($x^3$) en los parametros de x que va de -2 a 2

# %%
plot(x**2,adaptative=False,nb_of_points=10)

# %% [markdown]
# Marca los puntos para graficar (en este caso son 10 puntos)

# %% [markdown]
# ### Curvas parametrizadas

# %%
from sympy import plot_parametric

# %%
s=symbols('s')

# %%
plot_parametric((cos(s)),sin(s))

# %%
plot_parametric((cos(s),sin(s)),(s,s**2),(s,-4,4))

# %%
c2[0].line_color='green'

# %%
c2.show()

# %% [markdown]
# ### Graficas 3D

# %%
from sympy.plotting import plot3d

# %%
x,y=symbols('x y')

# %%
plot3d(x*y)

# %%
plot3d(x*y, (x,-5,5),(y,-5,5))

# %%
plot3d(x*y, -x*y, (x,-5,5),(y,-5,5))

# %%
plot3d((x**2 + y**2, (x,-5,5),(y,-5,5)),(x*y,(x,-3,3),(y,-3,3)))

# %%
from sympy.plotting import plot3d_parametric_line

# %%
plot3d_parametric_line(cos(s),sin(s),s)

# %%
plot3d_parametric_line((cos(s),sin(s),s,(s,-5,5)),(sin(s),s**2,s,(s,-5,5)))

# %%
from sympy.plotting import plot3d_parametric_surface

# %%
u, v =symbols('u v')

# %%
plot3d_parametric_surface(cos(u+v),sin(u-v),u-v)

# %%
plot3d_parametric_surface(cos(v)*cos(u),cos(v)*sin(u),sin(v))

# %% [markdown]
# Funciones implícitas

# %%
from sympy import plot_implicit, symbols, Eq, And

# %%
x, y = symbols(' x y')

# %%
p1 = plot_implicit(Eq(x**2 + y**2, 5))

# %%
p6 = plot_implicit(y > x**2)

# %%
p6 = plot_implicit(And(y > x, y > -x))

# %%
from sympy.plotting import plot3d

# %%
x,y=symbols('x y')

# %%
plot3d(x**3-x*y+y**3)

# %% [markdown]
# $T= x^3-xy+y^3$
