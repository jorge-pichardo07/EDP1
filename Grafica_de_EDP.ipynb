# %% [markdown]
# <a href="https://colab.research.google.com/github/jorge-pichardo07/EDP1/blob/main/Grafica_de_EDP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color="red">Esta es una gráfica de la parábola: $y=x^2$
# </font>

# %%
from IPython.display import Image

Image(url='https://i.gifer.com/7ooz.gif')
# Out:
# <img src="https://i.gifer.com/7ooz.gif"/>

# %%
import numpy as np
import matplotlib.pyplot as plt
x= np.linspace(-10,10,400)
y= x**2
plt.title('Grafica de $y=x^2$', color= 'violet')
plt.plot(x,y,label='y=x^2',color='violet')
plt.show()
